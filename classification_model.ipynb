# %% [markdown]
# **Building a Simple Decision Tree**

# %%
# !brew reinstall graphviz
# Out:
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.11.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:e5f8d1d7a
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg/manifests/9e
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg/blobs/sha256:4c19f39c827ee
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/blobs/sha256:ad97d175fa7
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.2.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:5cf57e838f218
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/manifests/2.3.3_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/blobs/sha256:40ea66d7bca0bb5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libffi/manifests/3.4.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libffi/blobs/sha256:6dbeaf8209b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre/manifests/8.45
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre/blobs/sha256:180d88dc2230e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/manifests/3.37.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/blobs/sha256:b3abf39f3b6
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/manifests/3.9.10
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/blobs/sha256:393f1d4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.70.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:9bb57ef98e408
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/manifests/2.0.33
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/blobs/sha256:7c7ae386ed0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/manifests/10.86.27
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/blobs/sha256:965ff8194e6
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gts/manifests/0.7.6_2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gts/blobs/sha256:8a0c9b4f60a2cb
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpthread-stubs/manifests/0.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpthread-stubs/blobs/sha256:4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2021.5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:97763c11
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.9
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:d10771f476b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:123c77fba
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.14_1-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:7f40d617b20
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.7.3.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:61f5bff3afe
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:20cc49734e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.10
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/blobs/sha256:cb7f488
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/blobs/sha256:c8f55ba0de8527
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.40.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:1862e6826a4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.16.0_5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/blobs/sha256:4a117545953b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/manifests/2.42.6
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/blobs/sha256:94835ab
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.11
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/blobs/sha256:9ae1580fef
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/manifests
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/blobs/sha
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/blobs/sha256:0831f474
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/69.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/blobs/sha256:3f75c907dadc
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/3.2.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:a1271e791
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.50.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/blobs/sha256:2e50912a0903
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/manifests/2.52.5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/blobs/sha256:9c6702f2d5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.4.6_4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/blobs/sha256:ad541ac37b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/manifests/2.50.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/blobs/sha256:633d24b7c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Reinstalling graphviz
# ==> Installing dependencies for graphviz: freetype, jpeg, giflib, webp, gd, libffi, pcre, sqlite, python@3.9, glib, jasper, netpbm, gts, libpthread-stubs, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, gdk-pixbuf, fribidi, gobject-introspection, graphite2, icu4c, harfbuzz, pango, librsvg and libtool
# ==> Installing graphviz dependency: freetype
# ==> Pouring freetype--2.11.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/freetype/2.11.1: 66 files, 2.3MB
# ==> Installing graphviz dependency: jpeg
# ==> Pouring jpeg--9e.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/jpeg/9e: 21 files, 953.8KB
# ==> Installing graphviz dependency: giflib
# ==> Pouring giflib--5.2.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/giflib/5.2.1: 19 files, 383.5KB
# ==> Installing graphviz dependency: webp
# ==> Pouring webp--1.2.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/webp/1.2.2: 41 files, 2.5MB
# ==> Installing graphviz dependency: gd
# ==> Pouring gd--2.3.3_1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/gd/2.3.3_1: 33 files, 1.4MB
# ==> Installing graphviz dependency: libffi
# ==> Pouring libffi--3.4.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libffi/3.4.2: 17 files, 599.8KB
# ==> Installing graphviz dependency: pcre
# ==> Pouring pcre--8.45.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/pcre/8.45: 204 files, 5.8MB
# ==> Installing graphviz dependency: sqlite
# ==> Pouring sqlite--3.37.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/sqlite/3.37.2: 11 files, 4.3MB
# ==> Installing graphviz dependency: python@3.9
# ==> Pouring python@3.9--3.9.10.catalina.bottle.tar.gz
# ==> /usr/local/Cellar/python@3.9/3.9.10/bin/python3 -m ensurepip
# ==> /usr/local/Cellar/python@3.9/3.9.10/bin/python3 -m pip install -v --no-deps
# 🍺  /usr/local/Cellar/python@3.9/3.9.10: 3,080 files, 55MB
# ==> Installing graphviz dependency: glib
# ==> Pouring glib--2.70.2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/glib/2.70.2: 444 files, 21.1MB
# ==> Installing graphviz dependency: jasper
# ==> Pouring jasper--2.0.33.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/jasper/2.0.33: 41 files, 1.3MB
# ==> Installing graphviz dependency: netpbm
# ==> Pouring netpbm--10.86.27.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/netpbm/10.86.27: 410 files, 17.7MB
# ==> Installing graphviz dependency: gts
# ==> Pouring gts--0.7.6_2.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/gts/0.7.6_2: 27 files, 1.1MB
# ==> Installing graphviz dependency: libpthread-stubs
# ==> Pouring libpthread-stubs--0.4.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libpthread-stubs/0.4: 5 files, 6.9KB
# ==> Installing graphviz dependency: xorgproto
# ==> Pouring xorgproto--2021.5.all.bottle.tar.gz
# 🍺  /usr/local/Cellar/xorgproto/2021.5: 264 files, 3.9MB
# ==> Installing graphviz dependency: libxau
# ==> Pouring libxau--1.0.9.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxau/1.0.9: 20 files, 117.8KB
# ==> Installing graphviz dependency: libxdmcp
# ==> Pouring libxdmcp--1.1.3.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxdmcp/1.1.3: 11 files, 125.5KB
# ==> Installing graphviz dependency: libxcb
# ==> Pouring libxcb--1.14_1.catalina.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/libxcb/1.14_1: 2,452 files, 6.9MB
# ==> Installing graphviz dependency: libx11
# ==> Pouring libx11--1.7.3.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libx11/1.7.3.1: 1,055 files, 7MB
# ==> Installing graphviz dependency: libxext
# ==> Pouring libxext--1.3.4.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxext/1.3.4: 87 files, 421KB
# ==> Installing graphviz dependency: libxrender
# ==> Pouring libxrender--0.9.10.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxrender/0.9.10: 12 files, 170KB
# ==> Installing graphviz dependency: lzo
# ==> Pouring lzo--2.10.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/lzo/2.10: 31 files, 546.9KB
# ==> Installing graphviz dependency: pixman
# ==> Pouring pixman--0.40.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/pixman/0.40.0: 14 files, 1.3MB
# ==> Installing graphviz dependency: cairo
# ==> Pouring cairo--1.16.0_5.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/cairo/1.16.0_5: 126 files, 6.3MB
# ==> Installing graphviz dependency: gdk-pixbuf
# ==> Pouring gdk-pixbuf--2.42.6.catalina.bottle.tar.gz
# ==> /usr/local/Cellar/gdk-pixbuf/2.42.6/bin/gdk-pixbuf-query-loaders --update-ca
# 🍺  /usr/local/Cellar/gdk-pixbuf/2.42.6: 147 files, 3.7MB
# ==> Installing graphviz dependency: fribidi
# ==> Pouring fribidi--1.0.11.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/fribidi/1.0.11: 67 files, 525.5KB
# ==> Installing graphviz dependency: gobject-introspection
# ==> Pouring gobject-introspection--1.70.0_3.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/gobject-introspection/1.70.0_3: 191 files, 13.0MB
# ==> Installing graphviz dependency: graphite2
# ==> Pouring graphite2--1.3.14.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/graphite2/1.3.14: 18 files, 235.7KB
# ==> Installing graphviz dependency: icu4c
# ==> Pouring icu4c--69.1.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/icu4c/69.1: 259 files, 72.8MB
# ==> Installing graphviz dependency: harfbuzz
# ==> Pouring harfbuzz--3.2.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/harfbuzz/3.2.0: 68 files, 7.5MB
# ==> Installing graphviz dependency: pango
# ==> Pouring pango--1.50.3.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/pango/1.50.3: 67 files, 3.3MB
# ==> Installing graphviz dependency: librsvg
# ==> Pouring librsvg--2.52.5.catalina.bottle.tar.gz
# ==> /usr/local/opt/gdk-pixbuf/bin/gdk-pixbuf-query-loaders --update-cache
# 🍺  /usr/local/Cellar/librsvg/2.52.5: 53 files, 57.6MB
# ==> Installing graphviz dependency: libtool
# ==> Pouring libtool--2.4.6_4.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libtool/2.4.6_4: 75 files, 3.7MB
# ==> Installing graphviz
# ==> Pouring graphviz--2.50.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/graphviz/2.50.0: 292 files, 6.9MB
# ==> Running `brew cleanup graphviz`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Upgrading 1 dependent:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ghostscript 9.54.0 -> 9.55.0
# ==> Downloading https://ghcr.io/v2/homebrew/core/ghostscript/manifests/9.55.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ghostscript/blobs/sha256:d53bb1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Upgrading ghostscript
#   9.54.0 -> 9.55.0
#
# ==> Pouring ghostscript--9.55.0.catalina.bottle.tar.gz
# Error: The `brew link` step did not complete successfully
# The formula built, but is not symlinked into /usr/local
# Could not symlink bin/dvipdf
# Target /usr/local/bin/dvipdf
# already exists. You may want to remove it:
#   rm '/usr/local/bin/dvipdf'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite ghostscript
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run ghostscript
#
# Possible conflicting files are:
# /usr/local/bin/dvipdf
# /usr/local/bin/eps2eps
# /usr/local/bin/gs -> /usr/local/bin/gs-noX11
# /usr/local/bin/gsbj
# /usr/local/bin/gsdj
# /usr/local/bin/gsdj500
# /usr/local/bin/gslj
# /usr/local/bin/gslp
# /usr/local/bin/gsnd
# /usr/local/bin/lprsetup.sh
# /usr/local/bin/pdf2dsc
# /usr/local/bin/pdf2ps
# /usr/local/bin/pf2afm
# /usr/local/bin/pfbtopfa
# /usr/local/bin/pphs
# /usr/local/bin/printafm
# /usr/local/bin/ps2ascii
# /usr/local/bin/ps2epsi
# /usr/local/bin/ps2pdf
# /usr/local/bin/ps2pdf12
# /usr/local/bin/ps2pdf13
# /usr/local/bin/ps2pdf14
# /usr/local/bin/ps2pdfwr
# /usr/local/bin/ps2ps
# /usr/local/bin/ps2ps2
# /usr/local/bin/unix-lpr.sh
# /usr/local/share/man/man1/dvipdf.1
# /usr/local/share/man/man1/eps2eps.1 -> /usr/local/share/man/man1/ps2ps.1
# /usr/local/share/man/man1/gs.1
# /usr/local/share/man/man1/gsbj.1 -> /usr/local/share/man/man1/gslp.1
# /usr/local/share/man/man1/gsdj.1 -> /usr/local/share/man/man1/gslp.1
# /usr/local/share/man/man1/gsdj500.1 -> /usr/local/share/man/man1/gslp.1
# /usr/local/share/man/man1/gslj.1 -> /usr/local/share/man/man1/gslp.1
# /usr/local/share/man/man1/gslp.1
# /usr/local/share/man/man1/gsnd.1
# /usr/local/share/man/man1/pdf2dsc.1
# /usr/local/share/man/man1/pdf2ps.1
# /usr/local/share/man/man1/pf2afm.1
# /usr/local/share/man/man1/pfbtopfa.1
# /usr/local/share/man/man1/printafm.1
# /usr/local/share/man/man1/ps2ascii.1
# /usr/local/share/man/man1/ps2epsi.1
# /usr/local/share/man/man1/ps2pdf.1
# /usr/local/share/man/man1/ps2pdf12.1 -> /usr/local/share/man/man1/ps2pdf.1
# /usr/local/share/man/man1/ps2pdf13.1 -> /usr/local/share/man/man1/ps2pdf.1
# /usr/local/share/man/man1/ps2pdf14.1 -> /usr/local/share/man/man1/ps2pdf.1
# /usr/local/share/man/man1/ps2pdfwr.1
# /usr/local/share/man/man1/ps2ps.1
# ==> Summary
# 🍺  /usr/local/Cellar/ghostscript/9.55.0: 683 files, 148.2MB
# ==> Running `brew cleanup ghostscript`...
# Removing: /usr/local/Cellar/ghostscript/9.54.0... (1,752 files, 181.7MB)
# Warning: Directory not empty @ dir_s_rmdir - /usr/local/Cellar/ghostscript/9.54.0
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!

# %%
# !pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Downloading dtreeviz-1.3.3.tar.gz (61 kB)
#      |████████████████████████████████| 61 kB 5.7 kB/s eta 0:00:011
# Collecting graphviz>=0.9
#   Downloading graphviz-0.19.1-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 14.2 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from dtreeviz) (1.3.2)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from dtreeviz) (1.20.3)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from dtreeviz) (1.0.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from dtreeviz) (3.4.3)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pytest in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from dtreeviz) (6.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from matplotlib->dtreeviz) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from matplotlib->dtreeviz) (8.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from matplotlib->dtreeviz) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from matplotlib->dtreeviz) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from matplotlib->dtreeviz) (0.10.0)
# Requirement already satisfied: six in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->dtreeviz) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from pandas->dtreeviz) (2021.1)
# Requirement already satisfied: attrs>=19.2.0 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from pytest->dtreeviz) (21.2.0)
# Requirement already satisfied: iniconfig in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from pytest->dtreeviz) (21.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from pytest->dtreeviz) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from pytest->dtreeviz) (1.10.0)
# Requirement already satisfied: toml in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from pytest->dtreeviz) (0.10.2)
# Requirement already satisfied: scipy>=1.1.0 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from scikit-learn->dtreeviz) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from scikit-learn->dtreeviz) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/envs/rdkit_2021_08/lib/python3.9/site-packages (from scikit-learn->dtreeviz) (1.1.0)
# Building wheels for collected packages: dtreeviz
#   Building wheel for dtreeviz (setup.py) ... done
#   Created wheel for dtreeviz: filename=dtreeviz-1.3.3-py3-none-any.whl size=67114 sha256=451282687814cfd0c97839e5843f4797bd2b48b495be29367a872cb6a231d5fd
#   Stored in directory: /Users/pwalters/Library/Caches/pip/wheels/15/2a/f4/3fc2b324bcf7d313af42eda3b1d77acf6c44b9cd62e93fc832
# Successfully built dtreeviz
# Installing collected packages: graphviz, colour, dtreeviz
# Successfully installed colour-0.1.5 dtreeviz-1.3.3 graphviz-0.19.1

# %%
import pandas as pd #data table manipulation
from rdkit import Chem # basic cheminformatics
from rdkit.Chem.Descriptors import MolWt, MolLogP, NumAromaticRings, NumHDonors, NumHAcceptors
import math #needed for log10
import seaborn as sns #plotting
from sklearn.tree import DecisionTreeClassifier, plot_tree # descision trees 
from sklearn.model_selection import train_test_split # split a dataset
from tqdm import tqdm # progress bar
from matplotlib import pyplot as plt # plotting
from dtreeviz.trees import * #plotting decision trees
from sklearn.metrics import roc_auc_score, matthews_corrcoef, cohen_kappa_score, plot_roc_curve, plot_confusion_matrix # model stats
from tdc.single_pred import ADME

# %% [markdown]
# Enable Pandas **progress_apply**

# %%
tqdm.pandas()

# %% [markdown]
# A simple function to calculate molecular weight, LogP, number of aromatic rings, number of hydrogen bond donors and acceptors from a SMILES

# %%
def calc_descriptors(smi):
    mol = Chem.MolFromSmiles(smi)
    if mol:
        Chem.DeleteSubstructs(mol, Chem.MolFromSmarts("[#1X0]"))
        mw, logp, num_arom_rings, hbd, hba = [x(mol) for x in [MolWt, MolLogP, NumAromaticRings, NumHDonors, NumHAcceptors]]
        res = [mw, logp, num_arom_rings, hbd, hba]
    else:
        res = [None] * 5
    return res

# %% [markdown]
# Read data from ["ESOL:  Estimating Aqueous Solubility Directly from Molecular Structure"](https://pubs.acs.org/doi/10.1021/ci034243x)

# %%
data = ADME(name = 'Solubility_AqSolDB')
sol_df = data.get_data()
# Out:
# Found local copy...
# Loading...
# Done!

# %%
sol_df
# Out:
#                                                 Drug_ID  \
# 0            N,N,N-trimethyloctadecan-1-aminium bromide
# 1                              Benzo[cd]indol-2(1H)-one
# 2                                  4-chlorobenzaldehyde
# 3     zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo...
# 4     4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth...
# ...                                                 ...
# 9977                                         tetracaine
# 9978                                       tetracycline
# 9979                                             thymol
# 9980                                          verapamil
# 9981                                           warfarin
#
#                                                    Drug         Y
# 0                   CCCCCCCCCCCCCCCCCC[N+](C)(C)C.[Br-] -3.616127
# 1                                  O=C1Nc2cccc3cccc1c23 -3.254767
# 2                                       O=Cc1ccc(Cl)cc1 -2.177078
# 3     CC(c1ccccc1)c1cc(C(=O)[O-])c(O)c(C(C)c2ccccc2)... -3.924409
# 4     c1cc(N(CC2CO2)CC2CO2)ccc1Cc1ccc(N(CC2CO2)CC2CO... -4.662065
# ...                                                 ...       ...
# 9977                       CCCCNc1ccc(C(=O)OCCN(C)C)cc1 -3.010000
# 9978  CN(C)[C@@H]1C(O)=C(C(N)=O)C(=O)[C@@]2(O)C(O)=C... -2.930000
# 9979                                Cc1ccc(C(C)C)c(O)c1 -2.190000
# 9980  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C... -3.980000
# 9981              CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O -4.780000
#
# [9982 rows x 3 columns]

# %%
sol_df.columns = ["Name","SMILES","LogS"]
sol_df
# Out:
#                                                    Name  \
# 0            N,N,N-trimethyloctadecan-1-aminium bromide
# 1                              Benzo[cd]indol-2(1H)-one
# 2                                  4-chlorobenzaldehyde
# 3     zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo...
# 4     4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth...
# ...                                                 ...
# 9977                                         tetracaine
# 9978                                       tetracycline
# 9979                                             thymol
# 9980                                          verapamil
# 9981                                           warfarin
#
#                                                  SMILES      LogS
# 0                   CCCCCCCCCCCCCCCCCC[N+](C)(C)C.[Br-] -3.616127
# 1                                  O=C1Nc2cccc3cccc1c23 -3.254767
# 2                                       O=Cc1ccc(Cl)cc1 -2.177078
# 3     CC(c1ccccc1)c1cc(C(=O)[O-])c(O)c(C(C)c2ccccc2)... -3.924409
# 4     c1cc(N(CC2CO2)CC2CO2)ccc1Cc1ccc(N(CC2CO2)CC2CO... -4.662065
# ...                                                 ...       ...
# 9977                       CCCCNc1ccc(C(=O)OCCN(C)C)cc1 -3.010000
# 9978  CN(C)[C@@H]1C(O)=C(C(N)=O)C(=O)[C@@]2(O)C(O)=C... -2.930000
# 9979                                Cc1ccc(C(C)C)c(O)c1 -2.190000
# 9980  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C... -3.980000
# 9981              CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O -4.780000
#
# [9982 rows x 3 columns]

# %%
sol_df = sol_df[['SMILES','Name','LogS']]
sol_df
# Out:
#                                                  SMILES  \
# 0                   CCCCCCCCCCCCCCCCCC[N+](C)(C)C.[Br-]
# 1                                  O=C1Nc2cccc3cccc1c23
# 2                                       O=Cc1ccc(Cl)cc1
# 3     CC(c1ccccc1)c1cc(C(=O)[O-])c(O)c(C(C)c2ccccc2)...
# 4     c1cc(N(CC2CO2)CC2CO2)ccc1Cc1ccc(N(CC2CO2)CC2CO...
# ...                                                 ...
# 9977                       CCCCNc1ccc(C(=O)OCCN(C)C)cc1
# 9978  CN(C)[C@@H]1C(O)=C(C(N)=O)C(=O)[C@@]2(O)C(O)=C...
# 9979                                Cc1ccc(C(C)C)c(O)c1
# 9980  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 9981              CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O
#
#                                                    Name      LogS
# 0            N,N,N-trimethyloctadecan-1-aminium bromide -3.616127
# 1                              Benzo[cd]indol-2(1H)-one -3.254767
# 2                                  4-chlorobenzaldehyde -2.177078
# 3     zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo... -3.924409
# 4     4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth... -4.662065
# ...                                                 ...       ...
# 9977                                         tetracaine -3.010000
# 9978                                       tetracycline -2.930000
# 9979                                             thymol -2.190000
# 9980                                          verapamil -3.980000
# 9981                                           warfarin -4.780000
#
# [9982 rows x 3 columns]

# %% [markdown]
# Add a new column "IsSol" to indicate whether a molecule's solubility is greater than 200uM

# %%
sol_df['IsSol'] = sol_df.LogS > math.log10(200 * 1e-6)

# %% [markdown]
# Plot solubility as a sanity check

# %%
sns.displot(x='LogS',hue="IsSol",data=sol_df)

# %% [markdown]
# Add the descriptors to the dataframe.  Note that all of the descriptors are going into one column called "desc".

# %%
sol_df['desc'] = sol_df.SMILES.progress_apply(calc_descriptors)
# Out:
#   3%|█▏                                    | 298/9982 [00:00<00:06, 1529.72it/s]RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
#   5%|█▊                                    | 469/9982 [00:00<00:05, 1610.28it/s][19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
#   7%|██▍                                   | 651/9982 [00:00<00:05, 1691.73it/s]RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
#   8%|███▏                                  | 821/9982 [00:00<00:05, 1694.39it/s]RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
#  10%|███▊                                  | 991/9982 [00:00<00:05, 1676.32it/s]RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
#  15%|█████▌                               | 1494/9982 [00:00<00:05, 1496.22it/s]RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
# [19:51:50] WARNING: not removing hydrogen atom without neighbors
#  16%|██████                               | 1646/9982 [00:01<00:06, 1321.70it/s]RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
#  18%|██████▌                              | 1783/9982 [00:01<00:06, 1276.18it/s]RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
#  19%|███████▏                             | 1934/9982 [00:01<00:06, 1335.15it/s]RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
#  21%|███████▊                             | 2122/9982 [00:01<00:05, 1482.73it/s]RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
#  23%|████████▍                            | 2287/9982 [00:01<00:05, 1527.79it/s]RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
#  25%|█████████                            | 2453/9982 [00:01<00:04, 1562.58it/s]RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
#  26%|█████████▋                           | 2612/9982 [00:01<00:04, 1545.11it/s]RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
#  30%|██████████▉                          | 2956/9982 [00:01<00:04, 1618.56it/s]RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
#  31%|███████████▌                         | 3119/9982 [00:02<00:04, 1608.86it/s]RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:51] WARNING: not removing hydrogen atom without neighbors
# [19:51:51] WARNING: not removing hydrogen atom without neighbors
#  33%|████████████▏                        | 3281/9982 [00:02<00:04, 1581.50it/s]RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
#  36%|█████████████▎                       | 3585/9982 [00:02<00:04, 1319.54it/s]RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
#  37%|█████████████▊                       | 3723/9982 [00:02<00:04, 1333.50it/s]RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
#  41%|███████████████▎                     | 4115/9982 [00:02<00:03, 1653.31it/s]RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
#  43%|███████████████▉                     | 4295/9982 [00:02<00:03, 1695.12it/s]RDKit WARNING: [19:51:52] WARNING: not removing hydrogen atom without neighbors
# [19:51:52] WARNING: not removing hydrogen atom without neighbors
#  47%|█████████████████▌                   | 4737/9982 [00:03<00:02, 1961.92it/s]RDKit WARNING: [19:51:53] WARNING: not removing hydrogen atom without neighbors
# [19:51:53] WARNING: not removing hydrogen atom without neighbors
#  53%|███████████████████▋                 | 5328/9982 [00:03<00:02, 1901.29it/s]RDKit WARNING: [19:51:53] WARNING: not removing hydrogen atom without neighbors
# [19:51:53] WARNING: not removing hydrogen atom without neighbors
#  57%|█████████████████████▏               | 5708/9982 [00:03<00:02, 1861.27it/s]RDKit WARNING: [19:51:53] WARNING: not removing hydrogen atom without neighbors
# [19:51:53] WARNING: not removing hydrogen atom without neighbors
#  61%|██████████████████████▌              | 6077/9982 [00:03<00:02, 1786.36it/s]RDKit WARNING: [19:51:53] WARNING: not removing hydrogen atom without neighbors
# [19:51:53] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [19:51:53] WARNING: not removing hydrogen atom without neighbors
# [19:51:53] WARNING: not removing hydrogen atom without neighbors
# 100%|█████████████████████████████████████| 9982/9982 [00:06<00:00, 1622.17it/s]

# %% [markdown]
# Split the descriptors into their on own columns.

# %%
desc_cols = ['MW','LogP','NumAromatic','HBD','HBA']
sol_df[desc_cols] = sol_df.desc.to_list()

# %% [markdown]
# We no longer need the "desc" column, let's get rid of it.

# %%
sol_df.drop("desc",axis=1,inplace=True)

# %% [markdown]
# Let's check the dataframe to make sure it's ok.

# %%
sol_df
# Out:
#                                                  SMILES  \
# 0                   CCCCCCCCCCCCCCCCCC[N+](C)(C)C.[Br-]
# 1                                  O=C1Nc2cccc3cccc1c23
# 2                                       O=Cc1ccc(Cl)cc1
# 3     CC(c1ccccc1)c1cc(C(=O)[O-])c(O)c(C(C)c2ccccc2)...
# 4     c1cc(N(CC2CO2)CC2CO2)ccc1Cc1ccc(N(CC2CO2)CC2CO...
# ...                                                 ...
# 9977                       CCCCNc1ccc(C(=O)OCCN(C)C)cc1
# 9978  CN(C)[C@@H]1C(O)=C(C(N)=O)C(=O)[C@@]2(O)C(O)=C...
# 9979                                Cc1ccc(C(C)C)c(O)c1
# 9980  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...
# 9981              CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O
#
#                                                    Name      LogS  IsSol  \
# 0            N,N,N-trimethyloctadecan-1-aminium bromide -3.616127   True
# 1                              Benzo[cd]indol-2(1H)-one -3.254767   True
# 2                                  4-chlorobenzaldehyde -2.177078   True
# 3     zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo... -3.924409  False
# 4     4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth... -4.662065  False
# ...                                                 ...       ...    ...
# 9977                                         tetracaine -3.010000   True
# 9978                                       tetracycline -2.930000   True
# 9979                                             thymol -2.190000   True
# 9980                                          verapamil -3.980000  False
# 9981                                           warfarin -4.780000  False
#
#            MW     LogP  NumAromatic  HBD  HBA
# 0     392.510  3.95810          0.0  0.0  0.0
# 1     169.183  2.40550          2.0  1.0  1.0
# 2     140.569  2.15250          1.0  0.0  1.0
# 3     756.226  8.11610          6.0  2.0  6.0
# 4     422.525  2.48540          2.0  0.0  6.0
# ...       ...      ...          ...  ...  ...
# 9977  264.369  2.61700          1.0  1.0  4.0
# 9978  444.440 -0.21440          1.0  6.0  9.0
# 9979  150.221  2.82402          1.0  1.0  1.0
# 9980  454.611  5.09308          2.0  0.0  6.0
# 9981  308.333  3.60960          3.0  1.0  4.0
#
# [9982 rows x 9 columns]

# %% [markdown]
# Split the data into training and test sets.

# %%
train, test = train_test_split(sol_df)

# %% [markdown]
# Split the training and test sets into X and y variables.

# %%
train_X = train[desc_cols]
train_y = train.IsSol
test_X = test[desc_cols]
test_y = test.IsSol

# %% [markdown]
# Create and train a classifier

# %%
cls = DecisionTreeClassifier(max_depth=2)
cls.fit(train_X,train_y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# Predict on the test set

# %%
pred = cls.predict(test_X)
auc, mcc, kappa = roc_auc_score(test_y, pred),matthews_corrcoef(test_y,pred),cohen_kappa_score(test_y,pred)
print(f"ROC AUC = {auc:.2f}")
print(f"Matthews Correlation Coefficient = {mcc:.2f}")
print(f"Cohen\'s Kappa = {kappa:.2f}")
# Out:
# ROC AUC = 0.81
# Matthews Correlation Coefficient = 0.65
# Cohen's Kappa = 0.64

# %% [markdown]
# Plot a confusion matrix to show the classifier performance

# %%
plot_confusion_matrix(cls,test_X,test_y)

# %% [markdown]
# Plot an ROC cure to show the classifier performance

# %%
plot_roc_curve(cls,test_X,test_y)

# %% [markdown]
# Use the default view from SciKit Learn to plot the decision tree

# %%
plt.rcParams["figure.figsize"] = (10,10)
plot_tree(cls,feature_names=desc_cols)
# Out:
# [Text(279.0, 453.0, 'LogP <= 3.116\ngini = 0.44\nsamples = 7486\nvalue = [2451, 5035]'),
#  Text(139.5, 271.8, 'LogP <= 2.559\ngini = 0.219\nsamples = 5282\nvalue = [662, 4620]'),
#  Text(69.75, 90.59999999999997, 'gini = 0.161\nsamples = 4579\nvalue = [404, 4175]'),
#  Text(209.25, 90.59999999999997, 'gini = 0.465\nsamples = 703\nvalue = [258, 445]'),
#  Text(418.5, 271.8, 'LogP <= 4.03\ngini = 0.306\nsamples = 2204\nvalue = [1789, 415]'),
#  Text(348.75, 90.59999999999997, 'gini = 0.451\nsamples = 851\nvalue = [559, 292]'),
#  Text(488.25, 90.59999999999997, 'gini = 0.165\nsamples = 1353\nvalue = [1230, 123]')]

# %% [markdown]
# Use dtreeviz to plot the decision tree

# %%
viz = dtreeviz(cls, train_X, train_y, feature_names = desc_cols, 
               target_name = "Solubility",class_names=["False","True"],scale=2)
viz

# %% [markdown]
# As a final check we're going to see if we can fit a model to incorrect data.  If we shuffle the y values, we shouldn't be able to get a good model.
#
# Shuffle the y-variable as a sanity check

# %%
sol_df['fake'] = sol_df.IsSol.sample(frac=1)

# %% [markdown]
# Split the dataframe into training a test sets.

# %%
fake_train, fake_test = train_test_split(sol_df)

# %% [markdown]
# Split the training and test sets into X and y variables

# %%
fake_train_X = fake_train[desc_cols]
fake_train_y = fake_train.fake
fake_test_X = fake_test[desc_cols]
fake_test_y = fake_test.fake

# %% [markdown]
# Build a classifer

# %%
fake_cls = DecisionTreeClassifier(max_depth=2)
fake_cls.fit(fake_train_X,fake_train_y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# Generate the predictions

# %%
fake_pred = fake_cls.predict(fake_test_X)

# %% [markdown]
# Calculate the AUC score

# %%
roc_auc_score(fake_test_y,pred)
# Out:
# 0.5083715484437508
